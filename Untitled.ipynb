# %% [markdown]
# # Chapter 1. Who are you?

# %% [markdown]
# What do you mostly want to do determines what do you
# Is there any batter place for ?

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('OQjrhIyaPyg')

# %%
import numpy as np
a = np.random.rand(100,100)
plt.imshow(a)

# %% [markdown]
# ### Open CV can be more advantageous

# %%
import numpy as np
x = np.random.randint(10)
print(x)
# Out:
# 9

# %% [markdown]
# ### MarkDown

# %% [markdown]
# # d

# %% [markdown]
# welcome

# %% [markdown]
# 한글 폰트
